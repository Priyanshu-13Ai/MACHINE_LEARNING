# %% [markdown]
# *FEATURE ENGINEERING*

# %% [markdown]
# 1. It is the process of using domain knowledge to extract features from raw data
# 2. These features can be used to improve the performance of ML Algorithms

# %% [markdown]
#                                   |Feature Engineering|
#                                   /      |
#                                  /       |
#                                 /        |
#                                /         |
#                               /          |
#                              /           |
#          |feature transformation|   |feature construction|
#                   |
#         1. Missing values
#         2.Outlier Detetction
#         3. feature engineering
